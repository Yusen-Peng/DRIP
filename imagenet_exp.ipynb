# %%
import torch

# test if cuda works
print("CUDA available:", torch.cuda.is_available())
# Out:
# CUDA available: True

# %%
print(f"Number of CUDA devices: {torch.cuda.device_count()}")
# Out:
# Number of CUDA devices: 1

# %%
# Out:
# python3: can't open file '/content/src/task1_newcodebase.py': [Errno 2] No such file or directory
